# %%
from selenium import webdriver

browser = webdriver.Chrome()
url = "https://www.webtoons.com/en/romance/letsplay/ep-168/viewer?title_no=1218&episode_no=176"

# %%
url = "https://www.webtoons.com/en/romance/letsplay/ep-168/viewer?title_no=1218&episode_no=176"
split_url = url.split("/")[5]
print(split_url)

# %%
import json
import os

if os.path.isfile('test_file.json'):
    pass
else:
    with open('test_file.json', 'w') as f:
        json.dump([], f)
        f.close()

with open('test_file.json', 'r') as f:
    data = json.load(f)
    print(type(data))

data.append('old')

with open('test_file.json', 'w') as f:
    json.dump(data, f)

# %%
str1 = '/home/cisco/GitLocal/Web-Scraper/raw_data/genres_and_webtoon_urls'
print(str1 + '/genres.py')

# %%
import json
import os

genres = ["DRAMA", "FANTASY", "SCI-FI"]
gen1 = genres[0]

animals = ["Dog", "Cat", "Mouse"]


if os.path.isfile('webtoon_urls.json'):
    pass
else:
    with open('webtoon_urls.json', 'w') as f:
        json.dump({}, f)

with open('webtoon_urls.json', 'r') as f:
    dict_of_wbt_links = json.load(f)

with open('webtoon_urls.json', 'w') as f:
    try:
        genre_links = dict_of_wbt_links[gen1]
        pass
    except KeyError:
        print(f'Current links = Empty')
        dict_of_wbt_links[gen1] = []
    
    json.dump(dict_of_wbt_links, f)
    
    print(f'Links = {genre_links}')

    # for animal in animals:
    #     if animal in genre_links:
    #         continue
    #     else:
    #         genre_links.append(animal)

# %%
import json

with open('raw_data/genres_and_webtoon_urls/webtoon_urls.json', 'r') as f:
    maindict = json.load(f)

total = 0

for key, value in maindict.items():
    print(f'{key} | {len(value)}')
    total = total + len(value)

print(f'\nTotal = {total}')

# %%
url = 'https://www.webtoons.com/en/romance/letsplay/list?title_no=1218'

name = url.split("/")[5]
print(name)

# %%
import json
from requests_futures.sessions import FuturesSession

with open('/home/cisco/GitLocal/Web-Scraper/raw_data/genres_and_webtoon_urls/webtoon_urls.json', 'r') as f:
    webtoon_dict = json.load(f)

for urls in webtoon_dict.values():
    with FuturesSession(max_workers=50) as session:
        futures = [session.get(url) for url in urls]
        for future in futures:
            resp = future.result()
            if resp.status_code == 200:
                print(resp)

# %%
import requests


url = requests.get('https://www.webtoons.com/en/romance/love-doesnt-talk/list?title_no=2140')
print(url.status_code)

# %%
import json
from concurrent.futures import ThreadPoolExecutor

with open('/home/cisco/GitLocal/Web-Scraper/raw_data/genres_and_webtoon_urls/webtoon_urls.json', 'r') as f:
    webtoon_dict = json.load(f)

def func(urls):
    with FuturesSession(max_workers=50) as session:
        futures = [session.get(url) for url in urls]
    return futures

for urls in webtoon_dict.values():
    with ThreadPoolExecutor(max_workers=50) as executor:
        futures = executor.submit(func, urls)
        print(futures.result())

# %%
import json
import requests

def main(urls):
    for url in urls:
        requests.get(url)

with open('/home/cisco/GitLocal/Web-Scraper/raw_data/genres_and_webtoon_urls/webtoon_urls.json', 'r') as f:
    webtoon_dict = json.load(f)

for urls in webtoon_dict.values():
    main(urls)

# %%
import json
import asyncio
import aiohttp

async def get_page(session, url):
    async with session.get(url) as r:
        return await r.text()

async def get_all(session, urls):
    tasks = []
    for url in urls:
        task = asyncio.create_task(get_page(session, url))
        tasks.append(task)
    results = await asyncio.gather(*tasks)
    return results

async def main(urls):
    async with aiohttp.ClientSession as session:
        data = await get_all(session, urls)
        return await data

if __name__=="__main__":
    results = asyncio.run(main(urls))

# %%
author = []

name = "Francisco Ryan Dias author info"

author.append(name[:-12])
print(author)

# %%
from multiprocessing import cpu_count

print(cpu_count())

# %%
str1 = '#180'

str2 = str1[1:]
print(str2)
print(type(str2))

int1 = int(str1[1:])
print(type(int1))

if int1 < 180:
    print("Under 180")
else:
    print("Not under 180")

# %%
listofints = [1, 3, 6, 7, 3 , 6, 9, 4, 7]

startnum = 10

while startnum >= 1:
    for int in listofints:
        if int == 1 or 3 or 6 or 7 or 4:
            pass
        else:
            break
    print("Not broken")
    startnum -= 1

print("Broke at 9")
print(startnum)

# %%
str1 = '171'
str2 = '99'
str3 = '1'
str4 = ''

print(len(str1))
print(len(str2))
print(len(str3))
print(len(str4))

# %%
import json
import requests

'''
302

:authority: www.webtoons.com
:method: GET
:path: /en/romance/letsplay/list?title_no=1218
:scheme: https
accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9
accept-encoding: gzip, deflate, br
accept-language: en-GB,en;q=0.9
sec-ch-ua: ".Not/A)Brand";v="99", "Google Chrome";v="103", "Chromium";v="103"
sec-ch-ua-mobile: ?0
sec-ch-ua-platform: "Linux"
sec-fetch-dest: document
sec-fetch-mode: navigate
sec-fetch-site: none
sec-fetch-user: ?1
upgrade-insecure-requests: 1
user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36
'''

'''
200

:authority: www.webtoons.com
:method: GET
:path: /en/romance/letsplay/list?title_no=1218
:scheme: https
accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9
accept-encoding: gzip, deflate, br
accept-language: en-GB,en;q=0.9
--cookie: locale=en; needGDPR=true; needCCPA=false; needCOPPA=false; countryCode=GB; timezoneOffset=+1; _ga=GA1.1.1725273679.1659791470; wtv=1; wts=1659791470249; wtu="6b8a6568b226d86730fc3ca90168e685"; pagGDPR=true; agpcGDPR_OTHERS=true; atGDPR=AD_CONSENT; agpcGDPR_DE=undefined; agpcGDPR_FR=undefined; agpcGDPR_ES=undefined; __gads=ID=6e1dc119fbac5857-224eef809ad400fd:T=1659791520:S=ALNI_MY99bXQYD8Vc9einoItVYxXQRgzUA; _ga_ZTE4EZ7DVX=GS1.1.1659791470.1.1.1659791535.59
--referer: https://www.webtoons.com/en/genre
sec-ch-ua: ".Not/A)Brand";v="99", "Google Chrome";v="103", "Chromium";v="103"
--sec-ch-ua-full-version-list: ".Not/A)Brand";v="99.0.0.0", "Google Chrome";v="103.0.5060.134", "Chromium";v="103.0.5060.134"
sec-ch-ua-mobile: ?0
--sec-ch-ua-model: ""
sec-ch-ua-platform: "Linux"
--sec-ch-ua-platform-version: "5.15.0"
sec-fetch-dest: document
sec-fetch-mode: navigate
--sec-fetch-site: cross-site
sec-fetch-user: ?1
upgrade-insecure-requests: 1
user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36
'''

# def check():
#     str1 = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36'
#     str2 = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36'
#     if str1 == str2:
#         print("The same")

# check()

# https://cc.loginfra.com/cc?a=gre.list&r=1&i=1218&bw=1350&px=271&py=344&sx=271&sy=344&m=1&nsc=webtoons.all&g=en_en&u=https://www.webtoons.com/en/romance/letsplay/list?title_no=1218
# https://cc.loginfra.com/cc?a=gre.list&r=2&i=2135&bw=1350&px=433&py=341&sx=433&sy=341&m=1&nsc=webtoons.all&g=en_en&u=https://www.webtoons.com/en/fantasy/the-remarried-empress/list?title_no=2135

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-GB,en;q=0.9',
    'cookie': 'locale=en; needGDPR=true; needCCPA=false; needCOPPA=false; countryCode=GB; timezoneOffset=+1; _ga=GA1.1.1725273679.1659791470; wtv=1; wts=1659791470249; wtu="6b8a6568b226d86730fc3ca90168e685"; pagGDPR=true; agpcGDPR_OTHERS=true; atGDPR=AD_CONSENT; agpcGDPR_DE=undefined; agpcGDPR_FR=undefined; agpcGDPR_ES=undefined; __gads=ID=6e1dc119fbac5857-224eef809ad400fd:T=1659791520:S=ALNI_MY99bXQYD8Vc9einoItVYxXQRgzUA; _ga_ZTE4EZ7DVX=GS1.1.1659791470.1.1.1659791535.59',
    'referer': 'https://www.webtoons.com/en/genre',
    'sec-ch-ua': '".Not/A)Brand";v="99", "Google Chrome";v="103", "Chromium";v="103"',
    'sec-ch-ua-full-version-list': '".Not/A)Brand";v="99.0.0.0", "Google Chrome";v="103.0.5060.134", "Chromium";v="103.0.5060.134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': "",
    'sec-ch-ua-platform': "Linux",
    'sec-ch-ua-platform-version': "5.15.0",
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'cross-site',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': str('1'),
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
}

with requests.Session() as session:
    with session.get('https://www.webtoons.com/en/fantasy/the-remarried-empress/list?title_no=2135', headers=headers) as response:
        assert response.status_code == 200
        print(response.text)
# Out:
# <!doctype html>
# <html lang="en">
# <head>
#
#
# <title>The Remarried Empress | WEBTOON</title>
# <meta name="keywords" content="The Remarried Empress, Fantasy, WEBTOON" />
# <meta name="description" content="Navier is the perfect empress, but when her husband brings a mistress into the palace, chaos ensues! Can she protect her own interests despite the scandal?" />
#
#
#
#
#
#
#
#
#
# <link rel="alternate" hreflang="en" href="https://www.webtoons.com/en/fantasy/the-remarried-empress/list?title_no=2135&page=1" />
#
# <link rel="alternate" hreflang="x-default" href="https://www.webtoons.com/en/fantasy/the-remarried-empress/list?title_no=2135&page=1" />
# <link rel="canonical" href="https://www.webtoons.com/en/fantasy/the-remarried-empress/list?title_no=2135&page=1" />
# <link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.webtoons.com/en/fantasy/the-remarried-empress/list?title_no=2135&page=1" />
#
#
#
#
#
#
#
#
#
#
#
#
# <meta charset="utf-8">
# ...

# %%
from selenium import webdriver
import time


driver = webdriver.Chrome()

driver.get('https://www.webtoons.com/en/romance/letsplay/list?title_no=1218', allow_redirects=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/cisco/GitLocal/Web-Scraper/_test.ipynb Cell 19 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/home/cisco/GitLocal/Web-Scraper/_test.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> import time
#       <a href='vscode-notebook-cell:/home/cisco/GitLocal/Web-Scraper/_test.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a> driver = webdriver.Chrome()
# ----> <a href='vscode-notebook-cell:/home/cisco/GitLocal/Web-Scraper/_test.ipynb#X25sZmlsZQ%3D%3D?line=6'>7</a> driver.get('https://www.webtoons.com/en/romance/letsplay/list?title_no=1218', allow_redirects=False)
#
# TypeError: WebDriver.get() got an unexpected keyword argument 'allow_redirects'
